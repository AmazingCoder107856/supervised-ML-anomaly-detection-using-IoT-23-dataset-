# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd

# %%
# capture4 = 'conn.log4.labeled'
# capture5 = 'conn.log5.labeled'
# capture7 = 'conn.log7.labeled'
capture1_1 = 'conn.log1_1.labeled'
capture3_1 = 'conn.log3_1.labeled'
capture7_1 = 'conn.log7_1.labeled'
capture8_1 = 'conn.log8_1.labeled'
capture9_1 = 'conn.log9_1.labeled'
capture17_1 = 'conn.log17_1.labeled'
capture20_1 = 'conn.log20_1.labeled'
capture21_1 = 'conn.log21_1.labeled'
capture33_1 = 'conn.log33_1.labeled'
capture34_1 = 'conn.log34_1.labeled'
capture35_1 = 'conn.log35_1.labeled'
capture36_1 = 'conn.log36_1.labeled'
capture39_1 = 'conn.log39_1.labeled'
capture42_1 = 'conn.log42_1.labeled'
capture43_1 = 'conn.log43_1.labeled'
capture44_1 = 'conn.log44_1.labeled'
capture48_1 = 'conn.log48_1.labeled'
capture49_1 = 'conn.log49_1.labeled'
capture52_1 = 'conn.log52_1.labeled'
capture60_1 = 'conn.log60_1.labeled'

# %%
# df4= pd.read_table(filepath_or_buffer=capture4, skiprows=10, nrows=100000)
# df4.columns=['ts',
#               'uid',
#               'id.orig_h',
#               'id.orig_p',
#               'id.resp_h',
#               'id.resp_p',
#               'proto',
#               'service',
#               'duration',
#               'orig_bytes',
#               'resp_bytes',
#               'conn_state',
#               'local_orig',
#               'local_resp',
#               'missed_bytes',
#               'history',
#               'orig_pkts',
#               'orig_ip_bytes',
#               'resp_pkts',
#               'resp_ip_bytes',
#               'label']
# df4.drop(df4.tail(1).index,inplace=True)

# %%
# df5= pd.read_table(filepath_or_buffer=capture5, skiprows=10, nrows=100000)
# df5.columns=['ts',
#               'uid',
#               'id.orig_h',
#               'id.orig_p',
#               'id.resp_h',
#               'id.resp_p',
#               'proto',
#               'service',
#               'duration',
#               'orig_bytes',
#               'resp_bytes',
#               'conn_state',
#               'local_orig',
#               'local_resp',
#               'missed_bytes',
#               'history',
#               'orig_pkts',
#               'orig_ip_bytes',
#               'resp_pkts',
#               'resp_ip_bytes',
#               'label']
# df5.drop(df5.tail(1).index,inplace=True)

# %%
# df7= pd.read_table(filepath_or_buffer=capture7, skiprows=10, nrows=100000)
# df7.columns=['ts',
#               'uid',
#               'id.orig_h',
#               'id.orig_p',
#               'id.resp_h',
#               'id.resp_p',
#               'proto',
#               'service',
#               'duration',
#               'orig_bytes',
#               'resp_bytes',
#               'conn_state',
#               'local_orig',
#               'local_resp',
#               'missed_bytes',
#               'history',
#               'orig_pkts',
#               'orig_ip_bytes',
#               'resp_pkts',
#               'resp_ip_bytes',
#               'label']
# df7.drop(df7.tail(1).index,inplace=True)

# %%
df1_1= pd.read_table(filepath_or_buffer=capture1_1, skiprows=10, nrows=100000)
df1_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df1_1.drop(df1_1.tail(1).index,inplace=True)

# %%
df3_1= pd.read_table(filepath_or_buffer=capture3_1, skiprows=10, nrows=100000)
df3_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df3_1.drop(df3_1.tail(1).index,inplace=True)

# %%
df7_1= pd.read_table(filepath_or_buffer=capture7_1, skiprows=10, nrows=100000)
df7_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df7_1.drop(df7_1.tail(1).index,inplace=True)

# %%
df8_1= pd.read_table(filepath_or_buffer=capture8_1, skiprows=10, nrows=100000)
df8_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df8_1.drop(df8_1.tail(1).index,inplace=True)

# %%
df9_1= pd.read_table(filepath_or_buffer=capture9_1, skiprows=10, nrows=100000)
df9_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df9_1.drop(df9_1.tail(1).index,inplace=True)

# %%
df17_1= pd.read_table(filepath_or_buffer=capture17_1, skiprows=10, nrows=100000)
df17_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df17_1.drop(df17_1.tail(1).index,inplace=True)

# %%
df20_1= pd.read_table(filepath_or_buffer=capture20_1, skiprows=10, nrows=100000)
df20_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df20_1.drop(df20_1.tail(1).index,inplace=True)

# %%
df21_1= pd.read_table(filepath_or_buffer=capture21_1, skiprows=10, nrows=100000)
df21_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df21_1.drop(df21_1.tail(1).index,inplace=True)

# %%
df33_1= pd.read_table(filepath_or_buffer=capture33_1, skiprows=10, nrows=100000)
df33_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df33_1.drop(df33_1.tail(1).index,inplace=True)

# %%
df34_1= pd.read_table(filepath_or_buffer=capture34_1, skiprows=10, nrows=100000)
df34_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df34_1.drop(df34_1.tail(1).index,inplace=True)

# %%
df35_1= pd.read_table(filepath_or_buffer=capture35_1, skiprows=10, nrows=100000)
df35_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df35_1.drop(df35_1.tail(1).index,inplace=True)

# %%
df36_1= pd.read_table(filepath_or_buffer=capture36_1, skiprows=10, nrows=100000)
df36_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df36_1.drop(df36_1.tail(1).index,inplace=True)

# %%
df39_1= pd.read_table(filepath_or_buffer=capture39_1, skiprows=10, nrows=100000)
df39_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df39_1.drop(df39_1.tail(1).index,inplace=True)

# %%
df42_1= pd.read_table(filepath_or_buffer=capture42_1, skiprows=10, nrows=100000)
df42_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df42_1.drop(df42_1.tail(1).index,inplace=True)

# %%
df43_1= pd.read_table(filepath_or_buffer=capture43_1, skiprows=10, nrows=100000)
df43_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df43_1.drop(df43_1.tail(1).index,inplace=True)

# %%
df44_1= pd.read_table(filepath_or_buffer=capture44_1, skiprows=10, nrows=100000)
df44_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df44_1.drop(df44_1.tail(1).index,inplace=True)

# %%
df48_1= pd.read_table(filepath_or_buffer=capture48_1, skiprows=10, nrows=100000)
df48_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df48_1.drop(df48_1.tail(1).index,inplace=True)

# %%
df49_1= pd.read_table(filepath_or_buffer=capture49_1, skiprows=10, nrows=100000)
df49_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df49_1.drop(df49_1.tail(1).index,inplace=True)

# %%
df52_1= pd.read_table(filepath_or_buffer=capture52_1, skiprows=10, nrows=100000)
df52_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df52_1.drop(df52_1.tail(1).index,inplace=True)

# %%
df60_1= pd.read_table(filepath_or_buffer=capture60_1, skiprows=10, nrows=100000)
df60_1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df60_1.drop(df60_1.tail(1).index,inplace=True)

# %%
frames=[df1_1,df3_1,df7_1,df8_1,df9_1,df17_1,df20_1,df21_1,df33_1,df34_1,df35_1,df36_1,df39_1,df42_1,df43_1,df44_1,df48_1,df49_1,df52_1,df60_1]

# %%
df_c=pd.concat(frames)

# %%
df_c
# Out:
#                       ts                 uid        id.orig_h  id.orig_p  \
# 0       1525879832.01624   CDe43c1PtgynajGI6  192.168.100.103    60905.0
# 1      1525879832.024985  CJaDcG3MZzvf1YVYI4  192.168.100.103    44301.0
# 2      1525879832.044975  CMBrup3BLXivSp4Avc  192.168.100.103    50244.0
# 3      1525879833.016171  CfHl9r3XMYtDQRrHnh  192.168.100.103    34243.0
# 4      1525879833.044906  C7USrA15nFVkniMqC5  192.168.100.103    34840.0
# ...                  ...                 ...              ...        ...
# 99994  1569018214.466954  CMwTZl4N2Q0IKi0Fgk    192.168.1.195     3318.0
# 99995  1569018209.467007  CEE7Bb1YnlZKy47L5j    192.168.1.195    42884.0
# 99996   1569018209.46701  CS9YeA2VI9fEwAogPe    192.168.1.195    61773.0
# 99997  1569018214.467203   Cye6NB3mnllDOP0h4    192.168.1.195    37271.0
# 99998  1569018214.467206  ChLpOm4dJANrZ8HEhe    192.168.1.195     5055.0
#
#              id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# ...

# %%
df_c.shape
# Out:
# (1444674, 21)

# %%
df_c['label'].value_counts()
# Out:
# label
# -   Malicious   PartOfAHorizontalPortScan          578916
# (empty)   Malicious   PartOfAHorizontalPortScan    247023
# -   Malicious   Okiru                              163016
# -   Benign   -                                     146275
# -   Malicious   DDoS                               138777
# (empty)   Malicious   Okiru                         99674
# (empty)   Benign   -                                51534
# (empty)   Malicious   C&C                            8229
# -   Malicious   C&C                                  6871
# (empty)   Malicious   Attack                         3814
# -   Malicious   C&C-HeartBeat                         227
# (empty)   Malicious   C&C-HeartBeat                   122
# -   Malicious   Attack                                101
# -   Malicious   C&C-FileDownload                       43
# -   Malicious   C&C-Torii                              30
# -   Malicious   FileDownload                           13
# ...

# %%
df_c.loc[(df_c.label == '-   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'PartOfAHorizontalPortScan'
df_c.loc[(df_c.label == '(empty)   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'PartOfAHorizontalPortScan'
df_c.loc[(df_c.label == '-   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '(empty)   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '-   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '(empty)   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '-   Malicious   DDoS'), 'label'] = 'DDoS'
df_c.loc[(df_c.label == '-   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '-   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '(empty)   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '-   Malicious   C&C-FileDownload'), 'label'] = 'C&C-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Torii'), 'label'] = 'C&C-Torii'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat-FileDownload'), 'label'] = 'C&C-HeartBeat-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   FileDownload'), 'label'] = 'FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Mirai'), 'label'] = 'C&C-Mirai'
df_c.loc[(df_c.label == '-   Malicious   Okiru-Attack'), 'label'] = 'Okiru-Attack'

# %%
df_c['label'].value_counts()
# Out:
# label
# PartOfAHorizontalPortScan     825939
# Okiru                         262690
# Benign                        197809
# DDoS                          138777
# C&C                            15100
# Attack                          3915
# C&C-HeartBeat                    349
# C&C-FileDownload                  43
# C&C-Torii                         30
# FileDownload                      13
# C&C-HeartBeat-FileDownload         8
# C&C-Mirai                          1
# Name: count, dtype: int64

# %%
pd.options.display.max_rows = 300
pd.options.display.max_columns = 300

# %%
# df_c = df_c.drop(columns=['ts','uid','id.orig_h','id.orig_p','id.resp_h','id.resp_p',
                               # 'service','local_orig','local_resp','history'])

# %%
# df_c = pd.get_dummies(df_c, columns=['proto'])
# df_c = pd.get_dummies(df_c, columns=['conn_state'])

# %%
df_c
# Out:
#                       ts                 uid        id.orig_h  id.orig_p  \
# 0       1525879832.01624   CDe43c1PtgynajGI6  192.168.100.103    60905.0
# 1      1525879832.024985  CJaDcG3MZzvf1YVYI4  192.168.100.103    44301.0
# 2      1525879832.044975  CMBrup3BLXivSp4Avc  192.168.100.103    50244.0
# 3      1525879833.016171  CfHl9r3XMYtDQRrHnh  192.168.100.103    34243.0
# 4      1525879833.044906  C7USrA15nFVkniMqC5  192.168.100.103    34840.0
# ...                  ...                 ...              ...        ...
# 99994  1569018214.466954  CMwTZl4N2Q0IKi0Fgk    192.168.1.195     3318.0
# 99995  1569018209.467007  CEE7Bb1YnlZKy47L5j    192.168.1.195    42884.0
# 99996   1569018209.46701  CS9YeA2VI9fEwAogPe    192.168.1.195    61773.0
# 99997  1569018214.467203   Cye6NB3mnllDOP0h4    192.168.1.195    37271.0
# 99998  1569018214.467206  ChLpOm4dJANrZ8HEhe    192.168.1.195     5055.0
#
#              id.resp_h  id.resp_p proto service  duration orig_bytes  \
# ...

# %%
df_c['duration'] = df_c['duration'].str.replace('-','0')
df_c['orig_bytes'] = df_c['orig_bytes'].str.replace('-','0')
df_c['resp_bytes'] = df_c['resp_bytes'].str.replace('-','0')

# %%
df_c.fillna(-1,inplace=True)

# %%
df_c.isna().sum()
# Out:
# ts               0
# uid              0
# id.orig_h        0
# id.orig_p        0
# id.resp_h        0
# id.resp_p        0
# proto            0
# service          0
# duration         0
# orig_bytes       0
# resp_bytes       0
# conn_state       0
# local_orig       0
# local_resp       0
# missed_bytes     0
# history          0
# orig_pkts        0
# orig_ip_bytes    0
# resp_pkts        0
# resp_ip_bytes    0
# label            0
# dtype: int64

# %%
print(df_c.columns.tolist())
# Out:
# ['ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p', 'proto', 'service', 'duration', 'orig_bytes', 'resp_bytes', 'conn_state', 'local_orig', 'local_resp', 'missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes', 'label']

# %%
df_c.to_csv('iot23_combined.csv')
